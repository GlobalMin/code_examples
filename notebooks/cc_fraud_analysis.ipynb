# %% [markdown]
# ## CC Fraud Analysis
#
# Let's load the models from our initial run and take a look at this dataset with them.

# %%
import os
import pickle

MODEL_OBJECTS_PATH = "model_objects"
FULL_PATH = os.path.join(os.path.dirname(os.getcwd()), "model_objects")

# %%
MODELS_TO_USE = [
    "CC Approval Data_xgboost_pipeline.pkl",
    "CC Approval Data_rf_pipeline.pkl",
    "CC Approval Data_lgbm_pipeline.pkl",
    "CC Approval Data_enet_pipeline.pkl",
]
# Loop over model_objects director
for model_object_file in os.listdir(FULL_PATH):
    if "CC Approval Data_xgboost_pipeline" in model_object_file:
        with open(os.path.join(FULL_PATH, model_object_file), "rb") as f:
            model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('preprocess',
#                  Pipeline(steps=[('preprocessor',
#                                   ColumnTransformer(transformers=[('num',
#                                                                    Pipeline(steps=[('imputer',
#                                                                                     SimpleImputer(strategy='median')),
#                                                                                    ('scaler',
#                                                                                     StandardScaler())]),
#                                                                    ['ID',
#                                                                     'CNT_CHILDREN',
#                                                                     'AMT_INCOME_TOTAL',
#                                                                     'DAYS_BIRTH',
# ...
